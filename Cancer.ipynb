# %%
#Importing Libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading data
df= pd.read_csv(r'C:\Users\ELHODA\Downloads\data.csv')

# %%
#small view of our data
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Shape of Data that we have 569 records and 33 feature
df.shape
# Out:
# (569, 33)

# %%
#Summary of data in table format
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
# Columns and their data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
#Dropping these columns that aren't useful
df=df.drop(columns=['Unnamed: 32','id'])

# %%
#Number of diagnosis that is Maliganit or benign
display(df['diagnosis'].value_counts())
sns.countplot(df['diagnosis'])
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#Here we plot a boxplot that show the range of M is bigger than B 
sns.catplot(x='diagnosis',y='texture_mean',data=df,kind='box')

# %%
#This desplay an strong relationship that when raduis mean increase the perimeter_mean
#There are an strong correlation that is 0.99
sns.scatterplot(x='radius_mean',y='perimeter_mean',data=df,hue='diagnosis',alpha=0.2 )
df[['radius_mean','perimeter_mean']].corr()
# Out:
#                 radius_mean  perimeter_mean
# radius_mean        1.000000        0.997855
# perimeter_mean     0.997855        1.000000

# %%
#This desplay an moderate relationship .
#There are an strong correlation that is 0.67
sns.lmplot(x='radius_mean',y='concavity_mean',data=df,hue='diagnosis' )
df[['radius_mean','concavity_mean']].corr()
# Out:
#                 radius_mean  concavity_mean
# radius_mean        1.000000        0.676764
# concavity_mean     0.676764        1.000000

# %%
#This desplay an low  association .
#There are an weak correlation that is 0.17
sns.lmplot(x='radius_mean',y='smoothness_mean',data=df,hue='diagnosis' )
df[['radius_mean','smoothness_mean']].corr()
# Out:
#                  radius_mean  smoothness_mean
# radius_mean         1.000000         0.170581
# smoothness_mean     0.170581         1.000000

# %%
reduis_malignant=df['radius_mean'][df['diagnosis']=='M']
reduis_benign=df['radius_mean'][df['diagnosis']=='B']

# %%
#Here we show the distribution  that we see from 5 to 18 is bengin
plt.figure(figsize=(10,10))
sns.distplot(reduis_malignant,label='Malignant')
sns.distplot(reduis_benign,label='benign')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['texture_mean'][df['diagnosis']=='M'],label='Malignant',kde=False)
sns.distplot(df['texture_mean'][df['diagnosis']=='B'],label='benign',kde=False)
plt.legend()

# %%
#This desplay an strong relationship that when raduis_worst increase the area_worst
#There are an strong correlation that is 0.98
sns.scatterplot(x=df['radius_worst'],y=df['area_worst'],hue=df['diagnosis'])
df[['radius_worst','area_worst']].corr()
# Out:
#               radius_worst  area_worst
# radius_worst      1.000000    0.984015
# area_worst        0.984015    1.000000

# %%
#This desplay an moderate association  
#There are an moderate correlation that is 0.34
sns.scatterplot(x=df['texture_worst'],y=df['area_worst'],hue=df['diagnosis'])
df[['texture_worst','area_worst']].corr()
# Out:
#                texture_worst  area_worst
# texture_worst       1.000000    0.345842
# area_worst          0.345842    1.000000

# %%
#Here a box plot that show that in B have small range and median in area_worst than M 
sns.boxplot(x=df['diagnosis'],y=df['area_worst'])

# %%
#Here a box plot that show that in B have small range and median in in radius_worst than M 
sns.boxplot(x=df['diagnosis'],y=df['radius_worst'])

# %%
#Here a box plot that show that in B have small range and median in compactness_worst than M 
sns.boxplot(x=df['diagnosis'],y=df['compactness_worst'])

# %%
#Here I deduce that in worst the B often be have lower range than M

# %%
#Create Data frame with columns that have mean word 
df_mean=df.filter(regex='_mean')

# %%
#Create Data frame with columns that have se word 
df_se=df.filter(regex='_se')
#Create Data frame with columns that have worst word 
df_worst=df.filter(regex='_worst')

# %%
#Here heatmap plot will show us all correlation in df_mean  
plt.figure(figsize=(10,10))
sns.heatmap(df_mean.corr(),annot=True)

# %%
#Here heatmap plot will show us all correlation in df_se
plt.figure(figsize=(10,10))
sns.heatmap(df_se.corr(),annot=True)

# %%
#Here heatmap plot will show us all correlation in df_worst 
plt.figure(figsize=(10,10))
sns.heatmap(df_worst.corr(),annot=True)
